# %% [markdown]
# #Tugas Matakuliah Komputer Cerdas Interaktif
#
# Salim Athari

# %% [markdown]
# ##Memanggil Paket dan penggunaannya
# - Memanggil paket library yang akan digunakan, dalam hal ini paket **json** dan **urllib.request**
# - Menggunakan paket untuk mengambil konten dari alamat API Bahasa pada wikipedia yang tersedia
# - Mengubah format data menjadi json menggunakan paket yang sebelumnya sudah dipanggil

# %%
import json,urllib.request

url = "https://commons.wikimedia.org/w/api.php?action=sitematrix&smtype=language&format=json"
data = urllib.request.urlopen(url).read()
output = json.loads(data)

# %% [markdown]
# ##Proses pencarian semua Bahasa yang tersedia di Wikipedia
# - Melakukan pencarian nama Bahasa tertentu dari hasil API Bahasa pada wikipedia
# - Menampilkan data sesuai pilihan, semua untuk menampilkan semua data atau sesuai kata yang dimasukkan
# - Melakukan pencarian halaman dari wikipedia sesuai kode yang dimasukkan
# - Menampilkan hasil pencarian secara raw maupun beutify

# %%
cari = input('Cari Bahasa (Masukkan kata / ketik "semua" untuk menampilkan semua): ')

jdt = 0
print('\n')
print('\033[1m','Kode\t: Nama Bahasa\t: Nama Latin','\033[0m')
print('------------------------------------')
for element in output['sitematrix']:
  lang = output['sitematrix'][element]
  if element!='count':
    if cari.lower() == 'semua':
      print(lang['code'],'\t: ',lang['name'],'\t: ',lang['localname'])
    elif cari.lower() in lang['name'].lower():
      print(lang['code'],'\t: ',lang['name'],'\t: ',lang['localname'])
      jdt += 1

#print(jdt)
if jdt>0:
  idlang = input('\nMasukkan kode: ')
  urlp = "https://"+idlang+".wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500"
  #print(urlp)

  datap = urllib.request.urlopen(urlp).read()
  outputp = json.loads(datap)
  fortam = input('\nFormat (raw/json)?: ')
  if fortam=='raw':
    print (outputp)
  elif fortam=='json':
    print (json.dumps(outputp, indent=4))
# Out:
# Cari Bahasa (Masukkan kata / ketik "semua" untuk menampilkan semua): aa
#
#
#  Kode	: Nama Bahasa	: Nama Latin
# ------------------------------------
# af 	:  Afrikaans 	:  Afrikaans
# dga 	:  Dagaare 	:  Dagaare
# kl 	:  kalaallisut 	:  Kalaallisut
# nv 	:  Diné bizaad 	:  Navajo
# so 	:  Soomaaliga 	:  Somali
#
# Masukkan kode: id
#
# Format (raw/json)?: json
# {
#     "batchcomplete": "",
#     "continue": {
#         "apcontinue": "(123509)_2000_WK183",
#         "continue": "-||"
#     },
#     "query": {
#         "allpages": [
#             {
#                 "pageid": 1577623,
#                 "ns": 0,
#                 "title": "!"
#             },
#             {
#                 "pageid": 697740,
#                 "ns": 0,
#                 "title": "!!! (album)"
#             },
#             {
#                 "pageid": 3358086,
#                 "ns": 0,
#                 "title": "!Kung"
#             },
#             {
#                 "pageid": 2175481,
#                 "ns": 0,
#                 "title": "\""
#             },
#             {
#                 "pageid": 290104,
#                 "ns": 0,
#                 "title": "\"Awas\""
#             },
#             {
#                 "pageid": 327251,
#                 "ns": 0,
#                 "title": "\"Corps Baret Biru\""
#             },
#             {
#                 "pageid": 2614625,
#                 "ns": 0,
#                 "title": "\"Crocodile\" Dundee"
#             },
#             {
#                 "pageid": 4151004,
#                 "ns": 0,
#                 "title": "\"Dirty\" Dominik Mysterio"
#             },
#             {
#                 "pageid": 105818,
#                 "ns": 0,
#                 "title": "\"Gang Dolly\""
#             },
#             {
#                 "pageid": 2991113,
#                 "ns": 0,
#                 "title": "\"Help!\" (lagu)"
#             },
#             {
#                 "pageid": 2664003,
#                 "ns": 0,
#                 "title": "\"Isis\" orang Suebi"
#             },
#             {
#                 "pageid": 1414225,
#                 "ns": 0,
#                 "title": "\"Laila\""
#             },
#             {
#                 "pageid": 290000,
#                 "ns": 0,
#                 "title": "\"Lelah Jiwaku\""
#             },
#             {
#                 "pageid": 1456814,
#                 "ns": 0,
#                 "title": "\"Macho Man\" Randy Savage"
#             },
#             {
#                 "pageid": 327824,
#                 "ns": 0,
#                 "title": "\"Manos\" The Hands of Fate"
#             },
#             {
#                 "pageid": 593380,
#                 "ns": 0,
#                 "title": "\"O\"-Jung.Ban.Hap."
#             },
#             {
#                 "pageid": 593653,
#                 "ns": 0,
#                 "title": "\"O\"-\u6b63\u30fb\u53cd\u30fb\u5408"
#             },
#             {
#                 "pageid": 1156233,
#                 "ns": 0,
#                 "title": "\"Para pekerja seluruh dunia, bersatulah!!!"
#             },
#             {
#                 "pageid": 3345301,
#                 "ns": 0,
#                 "title": "\"Pretty Little Liars: Original Sin\""
#             },
#             {
#                 "pageid": 82563,
#                 "ns": 0,
#                 "title": "\"Weird Al\" Yankovic"
#             },
#             {
#                 "pageid": 142567,
#                 "ns": 0,
#                 "title": "\"Weird Al\" Yankovic (album)"
#             },
#             {
#                 "pageid": 2069532,
#                 "ns": 0,
#                 "title": "\"Z\" no Chikai"
#             },
#             {
#                 "pageid": 2428333,
#                 "ns": 0,
#                 "title": "\"help!\" (lagu)"
#             },
#             {
#                 "pageid": 1099776,
#                 "ns": 0,
#                 "title": "\"o\"-jung.ban.hap."
#             },
#             {
#                 "pageid": 284448,
#                 "ns": 0,
#                 "title": "\"till death do us part\""
#             },
#             {
#                 "pageid": 1099777,
#                 "ns": 0,
#                 "title": "\"weird al\" yankovic"
#             },
#             {
#                 "pageid": 1099778,
#                 "ns": 0,
#                 "title": "\"weird al\" yankovic (album)"
#             },
#             {
#                 "pageid": 2186422,
#                 "ns": 0,
#                 "title": "\"z\" no chikai"
#             },
#             {
#                 "pageid": 271278,
#                 "ns": 0,
#                 "title": "$"
#             },
#             {
#                 "pageid": 3858763,
#                 "ns": 0,
#                 "title": "$30,000"
#             },
#             {
#                 "pageid": 4190517,
#                 "ns": 0,
#                 "title": "$456,000 Squid Game in Real Life!"
#             },
#             {
#                 "pageid": 459375,
#                 "ns": 0,
#                 "title": "$AS"
#             },
#             {
#                 "pageid": 2626841,
#                 "ns": 0,
#                 "title": "$pringfield (or, How I Learned to Stop Worrying and Love Legalized Gambling)"
#             },
#             {
#                 "pageid": 1565378,
#                 "ns": 0,
#                 "title": "%"
#             },
#             {
#                 "pageid": 26151,
#                 "ns": 0,
#                 "title": "&"
#             },
#             {
#                 "pageid": 2552887,
#                 "ns": 0,
#                 "title": "&10"
#             },
#             {
#                 "pageid": 3697442,
#                 "ns": 0,
#                 "title": "&AUDITION - The Howling"
#             },
#             {
#                 "pageid": 3955999,
#                 "ns": 0,
#                 "title": "&TEAM"
#             },
#             {
#                 "pageid": 2630802,
#                 "ns": 0,
#                 "title": "&TV"
#             },
#             {
#                 "pageid": 3834016,
#                 "ns": 0,
#                 "title": "&Team"
#             },
#             {
#                 "pageid": 3368628,
#                 "ns": 0,
#                 "title": "&Twice"
#             },
#             {
#                 "pageid": 2801422,
#                 "ns": 0,
#                 "title": "& TV"
#             },
#             {
#                 "pageid": 2631028,
#                 "ns": 0,
#                 "title": "&tv"
#             },
#             {
#                 "pageid": 2999456,
#                 "ns": 0,
#                 "title": "'"
#             },
#             {
#                 "pageid": 3864282,
#                 "ns": 0,
#                 "title": "'''Bolaang Uki''', Bolaang Uki, Bolaang Mongondow Selatan"
#             },
#             {
#                 "pageid": 3957210,
#                 "ns": 0,
#                 "title": "'''Miss Thailand International 2023'''"
#             },
#             {
#                 "pageid": 4218263,
#                 "ns": 0,
#                 "title": "''Food Estate''"
#             },
#             {
#                 "pageid": 3957209,
#                 "ns": 0,
#                 "title": "''Miss Thailand International 2023''"
#             },
#             {
#                 "pageid": 3498281,
#                 "ns": 0,
#                 "title": "''Polyodon spathula''"
#             },
#             {
#                 "pageid": 3877999,
#                 "ns": 0,
#                 "title": "''Strongyloides stercoralis''"
#             },
#             {
#                 "pageid": 3589639,
#                 "ns": 0,
#                 "title": "''Wes Tatas''"
#             },
#             {
#                 "pageid": 1569133,
#                 "ns": 0,
#                 "title": "'03 Bonnie & Clyde"
#             },
#             {
#                 "pageid": 2186423,
#                 "ns": 0,
#                 "title": "'03 bonnie & clyde"
#             },
#             {
#                 "pageid": 3608438,
#                 "ns": 0,
#                 "title": "'30 FIFA World Cup"
#             },
#             {
#                 "pageid": 3623856,
#                 "ns": 0,
#                 "title": "'32 Summer Olympic Games"
#             },
#             {
#                 "pageid": 3623857,
#                 "ns": 0,
#                 "title": "'32 Summer Olympics"
#             },
#             {
#                 "pageid": 3608437,
#                 "ns": 0,
#                 "title": "'34 FIFA World Cup"
#             },
#             {
#                 "pageid": 3623860,
#                 "ns": 0,
#                 "title": "'36 Olympic Winter Games"
#             },
#             {
#                 "pageid": 3623854,
#                 "ns": 0,
#                 "title": "'36 Summer Olympic Games"
#             },
#             {
#                 "pageid": 3623855,
#                 "ns": 0,
#                 "title": "'36 Summer Olympics"
#             },
#             {
#                 "pageid": 3623858,
#                 "ns": 0,
#                 "title": "'36 Winter Olympic Games"
#             },
#             {
#                 "pageid": 3623859,
#                 "ns": 0,
#                 "title": "'36 Winter Olympics"
#             },
#             {
#                 "pageid": 3608436,
#                 "ns": 0,
#                 "title": "'38 FIFA World Cup"
#             },
#             {
#                 "pageid": 2064859,
#                 "ns": 0,
#                 "title": "'38 \u2013 Vienna Before the Fall"
#             },
#             {
#                 "pageid": 3608433,
#                 "ns": 0,
#                 "title": "'50 FIFA World Cup"
#             },
#             {
#                 "pageid": 3608432,
#                 "ns": 0,
#                 "title": "'54 FIFA World Cup"
#             },
#             {
#                 "pageid": 3608430,
#                 "ns": 0,
#                 "title": "'58 FIFA World Cup"
#             },
#             {
#                 "pageid": 3608429,
#                 "ns": 0,
#                 "title": "'62 FIFA World Cup"
#             },
#             {
#                 "pageid": 3608428,
#                 "ns": 0,
#                 "title": "'66 FIFA World Cup"
#             },
#             {
#                 "pageid": 3608414,
#                 "ns": 0,
#                 "title": "'70 FIFA World Cup"
#             },
#             {
#                 "pageid": 3608417,
#                 "ns": 0,
#                 "title": "'74 FIFA World Cup"
#             },
#             {
#                 "pageid": 4205715,
#                 "ns": 0,
#                 "title": "'76 (film)"
#             },
#             {
#                 "pageid": 3610468,
#                 "ns": 0,
#                 "title": "'76 Summer Olympic Games"
#             },
#             {
#                 "pageid": 3610467,
#                 "ns": 0,
#                 "title": "'76 Summer Olympics"
#             },
#             {
#                 "pageid": 3608422,
#                 "ns": 0,
#                 "title": "'78 FIFA World Cup"
#             },
#             {
#                 "pageid": 3608423,
#                 "ns": 0,
#                 "title": "'82 FIFA World Cup"
#             },
#             {
#                 "pageid": 3611138,
#                 "ns": 0,
#                 "title": "'84 Olympic Winter Games"
#             },
#             {
#                 "pageid": 3610477,
#                 "ns": 0,
#                 "title": "'84 Summer Olympic Games"
#             },
#             {
#                 "pageid": 3610478,
#                 "ns": 0,
#                 "title": "'84 Summer Olympics"
#             },
#             {
#                 "pageid": 3611139,
#                 "ns": 0,
#                 "title": "'84 Winter Olympic Games"
#             },
#             {
#                 "pageid": 3611140,
#                 "ns": 0,
#                 "title": "'84 Winter Olympics"
#             },
#             {
#                 "pageid": 3608424,
#                 "ns": 0,
#                 "title": "'86 FIFA World Cup"
#             },
#             {
#                 "pageid": 3594474,
#                 "ns": 0,
#                 "title": "'88 Summer Olympic Games"
#             },
#             {
#                 "pageid": 3594475,
#                 "ns": 0,
#                 "title": "'88 Summer Olympics"
#             },
#             {
#                 "pageid": 3594476,
#                 "ns": 0,
#                 "title": "'88 Summer Paralympic Games"
#             },
#             {
#                 "pageid": 3594477,
#                 "ns": 0,
#                 "title": "'88 Summer Paralympics"
#             },
#             {
#                 "pageid": 3608425,
#                 "ns": 0,
#                 "title": "'90 FIFA World Cup"
#             },
#             {
#                 "pageid": 3623865,
#                 "ns": 0,
#                 "title": "'92 Olympic Winter Games"
#             },
#             {
#                 "pageid": 3594436,
#                 "ns": 0,
#                 "title": "'92 Summer Olympic Games"
#             },
#             {
#                 "pageid": 3594438,
#                 "ns": 0,
#                 "title": "'92 Summer Olympics"
#             },
#             {
#                 "pageid": 3594480,
#                 "ns": 0,
#                 "title": "'92 Summer Paralympic Games"
#             },
#             {
#                 "pageid": 3594481,
#                 "ns": 0,
#                 "title": "'92 Summer Paralympics"
#             },
#             {
#                 "pageid": 3594427,
#                 "ns": 0,
#                 "title": "'92 Winter Olympic Games"
#             },
#             {
#                 "pageid": 3594428,
#                 "ns": 0,
#                 "title": "'92 Winter Olympics"
#             },
#             {
#                 "pageid": 3608426,
#                 "ns": 0,
#                 "title": "'94 FIFA World Cup"
#             },
#             {
#                 "pageid": 3623861,
#                 "ns": 0,
#                 "title": "'94 Olympic Winter Games"
#             },
#             {
#                 "pageid": 3623862,
#                 "ns": 0,
#                 "title": "'94 Winter Olympic Games"
#             },
#             {
#                 "pageid": 3623863,
#                 "ns": 0,
#                 "title": "'94 Winter Olympics"
#             },
#             {
#                 "pageid": 3594470,
#                 "ns": 0,
#                 "title": "'96 Olympic Games"
#             },
#             {
#                 "pageid": 3594471,
#                 "ns": 0,
#                 "title": "'96 Olympics"
#             },
#             {
#                 "pageid": 3594472,
#                 "ns": 0,
#                 "title": "'96 Summer Olympic Games"
#             },
#             {
#                 "pageid": 3594473,
#                 "ns": 0,
#                 "title": "'96 Summer Olympics"
#             },
#             {
#                 "pageid": 3608427,
#                 "ns": 0,
#                 "title": "'98 FIFA World Cup"
#             },
#             {
#                 "pageid": 3594457,
#                 "ns": 0,
#                 "title": "'98 Olympic Games"
#             },
#             {
#                 "pageid": 3623864,
#                 "ns": 0,
#                 "title": "'98 Olympic Winter Games"
#             },
#             {
#                 "pageid": 3594456,
#                 "ns": 0,
#                 "title": "'98 Olympics"
#             },
#             {
#                 "pageid": 3594454,
#                 "ns": 0,
#                 "title": "'98 Winter Olympic Games"
#             },
#             {
#                 "pageid": 3594455,
#                 "ns": 0,
#                 "title": "'98 Winter Olympics"
#             },
#             {
#                 "pageid": 1400626,
#                 "ns": 0,
#                 "title": "'Aad"
#             },
#             {
#                 "pageid": 85124,
#                 "ns": 0,
#                 "title": "'Abd al-D\u00e2r bin Qushay"
#             },
#             {
#                 "pageid": 85112,
#                 "ns": 0,
#                 "title": "'Abd al-Man\u00e2f bin Qushay"
#             },
#             {
#                 "pageid": 81579,
#                 "ns": 0,
#                 "title": "'Abd al-Muththalib"
#             },
#             {
#                 "pageid": 81581,
#                 "ns": 0,
#                 "title": "'Abd al-Muththalib bin H\u00e2syim"
#             },
#             {
#                 "pageid": 2831048,
#                 "ns": 0,
#                 "title": "'Abdu'l-Bah\u00e1"
#             },
#             {
#                 "pageid": 3162911,
#                 "ns": 0,
#                 "title": "'Abdu'llah ibn Sa'ad"
#             },
#             {
#                 "pageid": 81578,
#                 "ns": 0,
#                 "title": "'Abdul-Muththalib"
#             },
#             {
#                 "pageid": 1600613,
#                 "ns": 0,
#                 "title": "'Abdul 'Aziz Ibn Sa'ud"
#             },
#             {
#                 "pageid": 224663,
#                 "ns": 0,
#                 "title": "'Abdul 'Aziz bin Sa'ud"
#             },
#             {
#                 "pageid": 250136,
#                 "ns": 0,
#                 "title": "'Abdul Fattah Isma'il"
#             },
#             {
#                 "pageid": 449750,
#                 "ns": 0,
#                 "title": "'Abdul Karim Qasim"
#             },
#             {
#                 "pageid": 469457,
#                 "ns": 0,
#                 "title": "'Abdul Kuri"
#             },
#             {
#                 "pageid": 1602490,
#                 "ns": 0,
#                 "title": "'Abdullah bin Muhammad al-Umawi"
#             },
#             {
#                 "pageid": 3162910,
#                 "ns": 0,
#                 "title": "'Abdullah ibn Sa'ad"
#             },
#             {
#                 "pageid": 230673,
#                 "ns": 0,
#                 "title": "'Abu Mush'ab az-Zarqawi"
#             },
#             {
#                 "pageid": 206586,
#                 "ns": 0,
#                 "title": "'Ain"
#             },
#             {
#                 "pageid": 2413224,
#                 "ns": 0,
#                 "title": "'Ain Ghazal"
#             },
#             {
#                 "pageid": 3784758,
#                 "ns": 0,
#                 "title": "'Aisyiyah"
#             },
#             {
#                 "pageid": 3110464,
#                 "ns": 0,
#                 "title": "'Ajjur"
#             },
#             {
#                 "pageid": 3109418,
#                 "ns": 0,
#                 "title": "'Akbara"
#             },
#             {
#                 "pageid": 305802,
#                 "ns": 0,
#                 "title": "'Akka"
#             },
#             {
#                 "pageid": 344457,
#                 "ns": 0,
#                 "title": "'Alamain"
#             },
#             {
#                 "pageid": 250132,
#                 "ns": 0,
#                 "title": "'Ali Nashir Muhammad al-Husaini"
#             },
#             {
#                 "pageid": 2382708,
#                 "ns": 0,
#                 "title": "'Alqamah bin Qais"
#             },
#             {
#                 "pageid": 411044,
#                 "ns": 0,
#                 "title": "'Amman"
#             },
#             {
#                 "pageid": 3953033,
#                 "ns": 0,
#                 "title": "'Amr bin Luhay"
#             },
#             {
#                 "pageid": 1877406,
#                 "ns": 0,
#                 "title": "'Arsy"
#             },
#             {
#                 "pageid": 259325,
#                 "ns": 0,
#                 "title": "'Asir"
#             },
#             {
#                 "pageid": 3296867,
#                 "ns": 0,
#                 "title": "'Atara"
#             },
#             {
#                 "pageid": 3625519,
#                 "ns": 0,
#                 "title": "'Azza"
#             },
#             {
#                 "pageid": 3211920,
#                 "ns": 0,
#                 "title": "'Cause You're My Boy"
#             },
#             {
#                 "pageid": 2600919,
#                 "ns": 0,
#                 "title": "'En Haseva"
#             },
#             {
#                 "pageid": 841355,
#                 "ns": 0,
#                 "title": "'Golden Rice'"
#             },
#             {
#                 "pageid": 121028,
#                 "ns": 0,
#                 "title": "'Idul Adha"
#             },
#             {
#                 "pageid": 121027,
#                 "ns": 0,
#                 "title": "'Idul Fithri"
#             },
#             {
#                 "pageid": 3641404,
#                 "ns": 0,
#                 "title": "'Isa"
#             },
#             {
#                 "pageid": 818405,
#                 "ns": 0,
#                 "title": "'Khadijah binti Khuwailid'"
#             },
#             {
#                 "pageid": 3349046,
#                 "ns": 0,
#                 "title": "'KuTahu,Tuhanku"
#             },
#             {
#                 "pageid": 2936939,
#                 "ns": 0,
#                 "title": "'Ku Berbahagia"
#             },
#             {
#                 "pageid": 3349108,
#                 "ns": 0,
#                 "title": "'Ku Bersandar PadaNya"
#             },
#             {
#                 "pageid": 3348917,
#                 "ns": 0,
#                 "title": "'Ku Berseru, Hai Dunia"
#             },
#             {
#                 "pageid": 3372865,
#                 "ns": 0,
#                 "title": "'Ku Datang Kepada-Mu"
#             },
#             {
#                 "pageid": 3348785,
#                 "ns": 0,
#                 "title": "'Ku Diberi Belas Kasihan"
#             },
#             {
#                 "pageid": 3349136,
#                 "ns": 0,
#                 "title": "'Ku Disalibkan dengan Tuhanku"
#             },
#             {
#                 "pageid": 3373023,
#                 "ns": 0,
#                 "title": "'Ku Diubahnya"
#             },
#             {
#                 "pageid": 3349120,
#                 "ns": 0,
#                 "title": "'Ku Heran, Allah Mau Memb'ri"
#             },
#             {
#                 "pageid": 3348889,
#                 "ns": 0,
#                 "title": "'Ku Heran, Jurus'lamatku"
#             },
#             {
#                 "pageid": 3348875,
#                 "ns": 0,
#                 "title": "'Ku Ingin Menghayati"
#             },
#             {
#                 "pageid": 3349171,
#                 "ns": 0,
#                 "title": "'Ku Ingin Menyerahkan"
#             },
#             {
#                 "pageid": 3373081,
#                 "ns": 0,
#                 "title": "'Ku Ingin Selalu Dekat Padamu"
#             },
#             {
#                 "pageid": 3372937,
#                 "ns": 0,
#                 "title": "'Ku Ini Adalah Musafir"
#             },
#             {
#                 "pageid": 3373046,
#                 "ns": 0,
#                 "title": "'Ku Ini Seorang Musafir"
#             },
#             {
#                 "pageid": 2936953,
#                 "ns": 0,
#                 "title": "'Ku Mau Berjalan dengan Jurus'lamatku"
#             },
#             {
#                 "pageid": 3349045,
#                 "ns": 0,
#                 "title": "'Ku Mengasihi Yesus, Tuhanku"
#             },
#             {
#                 "pageid": 3372898,
#                 "ns": 0,
#                 "title": "'Ku Sangat Suka Mendengar Namanya"
#             },
#             {
#                 "pageid": 1070114,
#                 "ns": 0,
#                 "title": "'Ku Suka Menuturkan"
#             },
#             {
#                 "pageid": 3372953,
#                 "ns": 0,
#                 "title": "'Ku Yakin Tuhan Tuntun Langkahku"
#             },
#             {
#                 "pageid": 2540145,
#                 "ns": 0,
#                 "title": "'Mant\u0161ebo"
#             },
#             {
#                 "pageid": 747872,
#                 "ns": 0,
#                 "title": "'Masenate Mohato dari Lesotho"
#             },
#             {
#                 "pageid": 64564,
#                 "ns": 0,
#                 "title": "'N Sync"
#             },
#             {
#                 "pageid": 2461573,
#                 "ns": 0,
#                 "title": "'Ndrangheta"
#             },
#             {
#                 "pageid": 417556,
#                 "ns": 0,
#                 "title": "'O Sole Mio"
#             },
#             {
#                 "pageid": 2346989,
#                 "ns": 0,
#                 "title": "'Otayyigah"
#             },
#             {
#                 "pageid": 594584,
#                 "ns": 0,
#                 "title": "'Padi Emas'"
#             },
#             {
#                 "pageid": 2628012,
#                 "ns": 0,
#                 "title": "'Round Springfield"
#             },
#             {
#                 "pageid": 2704115,
#                 "ns": 0,
#                 "title": "'Scuse Me While I Miss the Sky"
#             },
#             {
#                 "pageid": 284450,
#                 "ns": 0,
#                 "title": "'Til Death Do Us Part"
#             },
#             {
#                 "pageid": 2745235,
#                 "ns": 0,
#                 "title": "'Tis the 30th Season"
#             },
#             {
#                 "pageid": 2704602,
#                 "ns": 0,
#                 "title": "'Tis the Fifteenth Season"
#             },
#             {
#                 "pageid": 2719686,
#                 "ns": 0,
#                 "title": "'Ujaif bin 'Anbasa"
#             },
#             {
#                 "pageid": 2745452,
#                 "ns": 0,
#                 "title": "'Ujayf bin 'Anbasa"
#             },
#             {
#                 "pageid": 34649,
#                 "ns": 0,
#                 "title": "'Umar Khayyam"
#             },
#             {
#                 "pageid": 1174642,
#                 "ns": 0,
#                 "title": "'Umar bin 'Abdul 'Aziz"
#             },
#             {
#                 "pageid": 121087,
#                 "ns": 0,
#                 "title": "'Umar bin 'Abdul Aziz"
#             },
#             {
#                 "pageid": 1178863,
#                 "ns": 0,
#                 "title": "'Urf"
#             },
#             {
#                 "pageid": 2152330,
#                 "ns": 0,
#                 "title": "'Urwah, Madinah"
#             },
#             {
#                 "pageid": 793084,
#                 "ns": 0,
#                 "title": "'abdul kuri"
#             },
#             {
#                 "pageid": 2416190,
#                 "ns": 0,
#                 "title": "'ain ghazal"
#             },
#             {
#                 "pageid": 2173463,
#                 "ns": 0,
#                 "title": "'aisyiyah"
#             },
#             {
#                 "pageid": 2412638,
#                 "ns": 0,
#                 "title": "'alqamah bin qais"
#             },
#             {
#                 "pageid": 1099779,
#                 "ns": 0,
#                 "title": "'amr bin luhay"
#             },
#             {
#                 "pageid": 481296,
#                 "ns": 0,
#                 "title": "'arsy"
#             },
#             {
#                 "pageid": 3019920,
#                 "ns": 0,
#                 "title": "'im\u00e2mah"
#             },
#             {
#                 "pageid": 1099780,
#                 "ns": 0,
#                 "title": "'ku suka menuturkan"
#             },
#             {
#                 "pageid": 2540321,
#                 "ns": 0,
#                 "title": "'mant\u0161ebo"
#             },
#             {
#                 "pageid": 2610445,
#                 "ns": 0,
#                 "title": "'n Beetje"
#             },
#             {
#                 "pageid": 2610961,
#                 "ns": 0,
#                 "title": "'n beetje"
#             },
#             {
#                 "pageid": 570392,
#                 "ns": 0,
#                 "title": "'n sync"
#             },
#             {
#                 "pageid": 2461579,
#                 "ns": 0,
#                 "title": "'ndrangheta"
#             },
#             {
#                 "pageid": 572762,
#                 "ns": 0,
#                 "title": "'o sole mio"
#             },
#             {
#                 "pageid": 2412639,
#                 "ns": 0,
#                 "title": "'otayyigah"
#             },
#             {
#                 "pageid": 1806974,
#                 "ns": 0,
#                 "title": "'s-Gravendeel"
#             },
#             {
#                 "pageid": 47286,
#                 "ns": 0,
#                 "title": "'s-Gravenhage"
#             },
#             {
#                 "pageid": 42318,
#                 "ns": 0,
#                 "title": "'s-Hertogenbosch"
#             },
#             {
#                 "pageid": 2186425,
#                 "ns": 0,
#                 "title": "'s-gravendeel"
#             },
#             {
#                 "pageid": 1160385,
#                 "ns": 0,
#                 "title": "'s Gravenhage"
#             },
#             {
#                 "pageid": 361338,
#                 "ns": 0,
#                 "title": "'s Lands Plantentuin te Buitenzorg"
#             },
#             {
#                 "pageid": 2186424,
#                 "ns": 0,
#                 "title": "'urwah, madinah"
#             },
#             {
#                 "pageid": 679312,
#                 "ns": 0,
#                 "title": "'\u0627\u0644\u062c\u0645\u0647\u0648\u0631\u064a\u0629 \u0627\u0644\u0639\u0631\u0628\u064a\u0629 \u0627\u0644\u0635\u062d\u0631\u0627\u0648\u064a\u0629 \u0627\u0644\u062f\u064a\u0645\u0642\u0631\u0627\u0637\u064a\u0629"
#             },
#             {
#                 "pageid": 2175473,
#                 "ns": 0,
#                 "title": "("
#             },
#             {
#                 "pageid": 4224909,
#                 "ns": 0,
#                 "title": "(+)-Camphor 6-endo-hydroxylase"
#             },
#             {
#                 "pageid": 1859228,
#                 "ns": 0,
#                 "title": "(+)-Kamper 6-endo-hidroksilase"
#             },
#             {
#                 "pageid": 2186426,
#                 "ns": 0,
#                 "title": "(+)-camphor 6-endo-hydroxylase"
#             },
#             {
#                 "pageid": 3626684,
#                 "ns": 0,
#                 "title": "(+/-)"
#             },
#             {
#                 "pageid": 1224278,
#                 "ns": 0,
#                 "title": "(100004) 1983 VA"
#             },
#             {
#                 "pageid": 2186427,
#                 "ns": 0,
#                 "title": "(100004) 1983 va"
#             },
#             {
#                 "pageid": 1224273,
#                 "ns": 0,
#                 "title": "(100085) 1992 UY4"
#             },
#             {
#                 "pageid": 2186428,
#                 "ns": 0,
#                 "title": "(100085) 1992 uy4"
#             },
#             {
#                 "pageid": 1205395,
#                 "ns": 0,
#                 "title": "(100475) 1996 TZ36"
#             },
#             {
#                 "pageid": 2173467,
#                 "ns": 0,
#                 "title": "(100475) 1996 tz36"
#             },
#             {
#                 "pageid": 1205400,
#                 "ns": 0,
#                 "title": "(100619) 1997 TK14"
#             },
#             {
#                 "pageid": 2184257,
#                 "ns": 0,
#                 "title": "(100619) 1997 tk14"
#             },
#             {
#                 "pageid": 1205406,
#                 "ns": 0,
#                 "title": "(100624) 1997 TR28"
#             },
#             {
#                 "pageid": 2184258,
#                 "ns": 0,
#                 "title": "(100624) 1997 tr28"
#             },
#             {
#                 "pageid": 1215314,
#                 "ns": 0,
#                 "title": "(100756) 1998 FM5"
#             },
#             {
#                 "pageid": 2186429,
#                 "ns": 0,
#                 "title": "(100756) 1998 fm5"
#             },
#             {
#                 "pageid": 1215309,
#                 "ns": 0,
#                 "title": "(100926) 1998 MQ"
#             },
#             {
#                 "pageid": 2186430,
#                 "ns": 0,
#                 "title": "(100926) 1998 mq"
#             },
#             {
#                 "pageid": 1224657,
#                 "ns": 0,
#                 "title": "(10115) 1992 SK"
#             },
#             {
#                 "pageid": 2186431,
#                 "ns": 0,
#                 "title": "(10115) 1992 sk"
#             },
#             {
#                 "pageid": 1205411,
#                 "ns": 0,
#                 "title": "(101405) 1998 VJ3"
#             },
#             {
#                 "pageid": 2184259,
#                 "ns": 0,
#                 "title": "(101405) 1998 vj3"
#             },
#             {
#                 "pageid": 1224651,
#                 "ns": 0,
#                 "title": "(10145) 1994 CK1"
#             },
#             {
#                 "pageid": 2186432,
#                 "ns": 0,
#                 "title": "(10145) 1994 ck1"
#             },
#             {
#                 "pageid": 1205416,
#                 "ns": 0,
#                 "title": "(101466) 1998 WJ15"
#             },
#             {
#                 "pageid": 2184260,
#                 "ns": 0,
#                 "title": "(101466) 1998 wj15"
#             },
#             {
#                 "pageid": 1205420,
#                 "ns": 0,
#                 "title": "(101492) 1998 XT1"
#             },
#             {
#                 "pageid": 2186433,
#                 "ns": 0,
#                 "title": "(101492) 1998 xt1"
#             },
#             {
#                 "pageid": 1215882,
#                 "ns": 0,
#                 "title": "(10150) 1994 PN"
#             },
#             {
#                 "pageid": 2186434,
#                 "ns": 0,
#                 "title": "(10150) 1994 pn"
#             },
#             {
#                 "pageid": 1205425,
#                 "ns": 0,
#                 "title": "(101612) 1999 CS8"
#             },
#             {
#                 "pageid": 2186435,
#                 "ns": 0,
#                 "title": "(101612) 1999 cs8"
#             },
#             {
#                 "pageid": 1224647,
#                 "ns": 0,
#                 "title": "(10165) 1995 BL2"
#             },
#             {
#                 "pageid": 2186436,
#                 "ns": 0,
#                 "title": "(10165) 1995 bl2"
#             },
#             {
#                 "pageid": 1224269,
#                 "ns": 0,
#                 "title": "(101869) 1999 MM"
#             },
#             {
#                 "pageid": 2186437,
#                 "ns": 0,
#                 "title": "(101869) 1999 mm"
#             },
#             {
#                 "pageid": 1215306,
#                 "ns": 0,
#                 "title": "(101873) 1999 NC5"
#             },
#             {
#                 "pageid": 2186438,
#                 "ns": 0,
#                 "title": "(101873) 1999 nc5"
#             },
#             {
#                 "pageid": 1215302,
#                 "ns": 0,
#                 "title": "(102873) 1999 WK11"
#             },
#             {
#                 "pageid": 2186439,
#                 "ns": 0,
#                 "title": "(102873) 1999 wk11"
#             },
#             {
#                 "pageid": 1215878,
#                 "ns": 0,
#                 "title": "(10302) 1989 ML"
#             },
#             {
#                 "pageid": 2186440,
#                 "ns": 0,
#                 "title": "(10302) 1989 ml"
#             },
#             {
#                 "pageid": 1224263,
#                 "ns": 0,
#                 "title": "(103067) 1999 XA143"
#             },
#             {
#                 "pageid": 2186441,
#                 "ns": 0,
#                 "title": "(103067) 1999 xa143"
#             },
#             {
#                 "pageid": 1205430,
#                 "ns": 0,
#                 "title": "(103508) 2000 BV1"
#             },
#             {
#                 "pageid": 2186442,
#                 "ns": 0,
#                 "title": "(103508) 2000 bv1"
#             },
#             {
#                 "pageid": 1205436,
#                 "ns": 0,
#                 "title": "(103989) 2000 DC94"
#             },
#             {
#                 "pageid": 2186443,
#                 "ns": 0,
#                 "title": "(103989) 2000 dc94"
#             },
#             {
#                 "pageid": 1225497,
#                 "ns": 0,
#                 "title": "(105140) 2000 NL10"
#             },
#             {
#                 "pageid": 2186444,
#                 "ns": 0,
#                 "title": "(105140) 2000 nl10"
#             },
#             {
#                 "pageid": 1215295,
#                 "ns": 0,
#                 "title": "(105141) 2000 NF11"
#             },
#             {
#                 "pageid": 2186445,
#                 "ns": 0,
#                 "title": "(105141) 2000 nf11"
#             },
#             {
#                 "pageid": 1205441,
#                 "ns": 0,
#                 "title": "(105654) 2000 SX26"
#             },
#             {
#                 "pageid": 2186446,
#                 "ns": 0,
#                 "title": "(105654) 2000 sx26"
#             },
#             {
#                 "pageid": 1205445,
#                 "ns": 0,
#                 "title": "(105685) 2000 SC51"
#             },
#             {
#                 "pageid": 2186447,
#                 "ns": 0,
#                 "title": "(105685) 2000 sc51"
#             },
#             {
#                 "pageid": 1205452,
#                 "ns": 0,
#                 "title": "(105694) 2000 SV62"
#             },
#             {
#                 "pageid": 2186448,
#                 "ns": 0,
#                 "title": "(105694) 2000 sv62"
#             },
#             {
#                 "pageid": 1205456,
#                 "ns": 0,
#                 "title": "(105720) 2000 SR79"
#             },
#             {
#                 "pageid": 2186449,
#                 "ns": 0,
#                 "title": "(105720) 2000 sr79"
#             },
#             {
#                 "pageid": 1205460,
#                 "ns": 0,
#                 "title": "(105746) 2000 SP92"
#             },
#             {
#                 "pageid": 2186450,
#                 "ns": 0,
#                 "title": "(105746) 2000 sp92"
#             },
#             {
#                 "pageid": 1205467,
#                 "ns": 0,
#                 "title": "(105803) 2000 SH132"
#             },
#             {
#                 "pageid": 2186451,
#                 "ns": 0,
#                 "title": "(105803) 2000 sh132"
#             },
#             {
#                 "pageid": 1205470,
#                 "ns": 0,
#                 "title": "(105808) 2000 SZ135"
#             },
#             {
#                 "pageid": 2186452,
#                 "ns": 0,
#                 "title": "(105808) 2000 sz135"
#             },
#             {
#                 "pageid": 1205478,
#                 "ns": 0,
#                 "title": "(105896) 2000 SG187"
#             },
#             {
#                 "pageid": 2186453,
#                 "ns": 0,
#                 "title": "(105896) 2000 sg187"
#             },
#             {
#                 "pageid": 1205482,
#                 "ns": 0,
#                 "title": "(105901) 2000 SG192"
#             },
#             {
#                 "pageid": 2186454,
#                 "ns": 0,
#                 "title": "(105901) 2000 sg192"
#             },
#             {
#                 "pageid": 1205489,
#                 "ns": 0,
#                 "title": "(105904) 2000 SB197"
#             },
#             {
#                 "pageid": 2186455,
#                 "ns": 0,
#                 "title": "(105904) 2000 sb197"
#             },
#             {
#                 "pageid": 1205491,
#                 "ns": 0,
#                 "title": "(106001) 2000 SR283"
#             },
#             {
#                 "pageid": 2186456,
#                 "ns": 0,
#                 "title": "(106001) 2000 sr283"
#             },
#             {
#                 "pageid": 1205497,
#                 "ns": 0,
#                 "title": "(106060) 2000 SS316"
#             },
#             {
#                 "pageid": 2186457,
#                 "ns": 0,
#                 "title": "(106060) 2000 ss316"
#             },
#             {
#                 "pageid": 1205502,
#                 "ns": 0,
#                 "title": "(106091) 2000 SZ361"
#             },
#             {
#                 "pageid": 2186458,
#                 "ns": 0,
#                 "title": "(106091) 2000 sz361"
#             },
#             {
#                 "pageid": 1205507,
#                 "ns": 0,
#                 "title": "(106143) 2000 TU44"
#             },
#             {
#                 "pageid": 2186459,
#                 "ns": 0,
#                 "title": "(106143) 2000 tu44"
#             },
#             {
#                 "pageid": 1205514,
#                 "ns": 0,
#                 "title": "(106160) 2000 TG61"
#             },
#             {
#                 "pageid": 2186460,
#                 "ns": 0,
#                 "title": "(106160) 2000 tg61"
#             },
#             {
#                 "pageid": 1224642,
#                 "ns": 0,
#                 "title": "(10636) 1998 QK56"
#             },
#             {
#                 "pageid": 2186461,
#                 "ns": 0,
#                 "title": "(10636) 1998 qk56"
#             },
#             {
#                 "pageid": 1224259,
#                 "ns": 0,
#                 "title": "(106538) 2000 WK63"
#             },
#             {
#                 "pageid": 2186462,
#                 "ns": 0,
#                 "title": "(106538) 2000 wk63"
#             },
#             {
#                 "pageid": 1224256,
#                 "ns": 0,
#                 "title": "(106589) 2000 WN107"
#             },
#             {
#                 "pageid": 2186463,
#                 "ns": 0,
#                 "title": "(106589) 2000 wn107"
#             },
#             {
#                 "pageid": 1205517,
#                 "ns": 0,
#                 "title": "(107004) 2000 YC112"
#             },
#             {
#                 "pageid": 2186464,
#                 "ns": 0,
#                 "title": "(107004) 2000 yc112"
#             },
#             {
#                 "pageid": 1205523,
#                 "ns": 0,
#                 "title": "(107134) 2001 AE51"
#             },
#             {
#                 "pageid": 2186465,
#                 "ns": 0,
#                 "title": "(107134) 2001 ae51"
#             },
#             {
#                 "pageid": 1205530,
#                 "ns": 0,
#                 "title": "(107178) 2001 BE25"
#             },
#             {
#                 "pageid": 2186466,
#                 "ns": 0,
#                 "title": "(107178) 2001 be25"
#             },
#             {
#                 "pageid": 1205535,
#                 "ns": 0,
#                 "title": "(107804) 2001 FV58"
#             },
#             {
#                 "pageid": 2186467,
#                 "ns": 0,
#                 "title": "(107804) 2001 fv58"
#             },
#             {
#                 "pageid": 1215289,
#                 "ns": 0,
#                 "title": "(108519) 2001 LF"
#             },
#             {
#                 "pageid": 2186468,
#                 "ns": 0,
#                 "title": "(108519) 2001 lf"
#             },
#             {
#                 "pageid": 1215870,
#                 "ns": 0,
#                 "title": "(10860) 1995 LE"
#             },
#             {
#                 "pageid": 2186469,
#                 "ns": 0,
#                 "title": "(10860) 1995 le"
#             },
#             {
#                 "pageid": 1224250,
#                 "ns": 0,
#                 "title": "(108906) 2001 PL9"
#             },
#             {
#                 "pageid": 2186470,
#                 "ns": 0,
#                 "title": "(108906) 2001 pl9"
#             },
#             {
#                 "pageid": 1205538,
#                 "ns": 0,
#                 "title": "(109266) 2001 QL110"
#             },
#             {
#                 "pageid": 2186471,
#                 "ns": 0,
#                 "title": "(109266) 2001 ql110"
#             },
#             {
#                 "pageid": 1205543,
#                 "ns": 0,
#                 "title": "(109549) 2001 QM257"
#             },
#             {
#                 "pageid": 2186472,
#                 "ns": 0,
#                 "title": "(109549) 2001 qm257"
#             },
#             {
#                 "pageid": 1205548,
#                 "ns": 0,
#                 "title": "(110359) 2001 SA318"
#             },
#             {
#                 "pageid": 2186473,
#                 "ns": 0,
#                 "title": "(110359) 2001 sa318"
#             },
#             {
#                 "pageid": 1205552,
#                 "ns": 0,
#                 "title": "(110380) 2001 SO343"
#             },
#             {
#                 "pageid": 2186474,
#                 "ns": 0,
#                 "title": "(110380) 2001 so343"
#             },
#             {
#                 "pageid": 1215864,
#                 "ns": 0,
#                 "title": "(11054) 1991 FA"
#             },
#             {
#                 "pageid": 2186475,
#                 "ns": 0,
#                 "title": "(11054) 1991 fa"
#             },
#             {
#                 "pageid": 1205558,
#                 "ns": 0,
#                 "title": "(110563) 2001 TQ109"
#             },
#             {
#                 "pageid": 2186476,
#                 "ns": 0,
#                 "title": "(110563) 2001 tq109"
#             },
#             {
#                 "pageid": 1205563,
#                 "ns": 0,
#                 "title": "(110829) 2001 UT54"
#             },
#             {
#                 "pageid": 2186477,
#                 "ns": 0,
#                 "title": "(110829) 2001 ut54"
#             },
#             {
#                 "pageid": 1205568,
#                 "ns": 0,
#                 "title": "(110832) 2001 UA58"
#             },
#             {
#                 "pageid": 2186478,
#                 "ns": 0,
#                 "title": "(110832) 2001 ua58"
#             },
#             {
#                 "pageid": 1205573,
#                 "ns": 0,
#                 "title": "(110859) 2001 UW79"
#             },
#             {
#                 "pageid": 2186479,
#                 "ns": 0,
#                 "title": "(110859) 2001 uw79"
#             },
#             {
#                 "pageid": 1201980,
#                 "ns": 0,
#                 "title": "(11089) 1994 CS8"
#             },
#             {
#                 "pageid": 2186480,
#                 "ns": 0,
#                 "title": "(11089) 1994 cs8"
#             },
#             {
#                 "pageid": 1205577,
#                 "ns": 0,
#                 "title": "(111113) 2001 VK85"
#             },
#             {
#                 "pageid": 2186481,
#                 "ns": 0,
#                 "title": "(111113) 2001 vk85"
#             },
#             {
#                 "pageid": 1205582,
#                 "ns": 0,
#                 "title": "(111198) 2001 WX20"
#             },
#             {
#                 "pageid": 2186482,
#                 "ns": 0,
#                 "title": "(111198) 2001 wx20"
#             },
#             {
#                 "pageid": 1205588,
#                 "ns": 0,
#                 "title": "(111231) 2001 WM60"
#             },
#             {
#                 "pageid": 2186483,
#                 "ns": 0,
#                 "title": "(111231) 2001 wm60"
#             },
#             {
#                 "pageid": 1224247,
#                 "ns": 0,
#                 "title": "(111253) 2001 XU10"
#             },
#             {
#                 "pageid": 2186484,
#                 "ns": 0,
#                 "title": "(111253) 2001 xu10"
#             },
#             {
#                 "pageid": 1205593,
#                 "ns": 0,
#                 "title": "(111571) 2002 AD13"
#             },
#             {
#                 "pageid": 2186485,
#                 "ns": 0,
#                 "title": "(111571) 2002 ad13"
#             },
#             {
#                 "pageid": 1205598,
#                 "ns": 0,
#                 "title": "(111736) 2002 CH76"
#             },
#             {
#                 "pageid": 2186486,
#                 "ns": 0,
#                 "title": "(111736) 2002 ch76"
#             },
#             {
#                 "pageid": 1205602,
#                 "ns": 0,
#                 "title": "(111770) 2002 CY152"
#             },
#             {
#                 "pageid": 2186487,
#                 "ns": 0,
#                 "title": "(111770) 2002 cy152"
#             },
#             {
#                 "pageid": 1205608,
#                 "ns": 0,
#                 "title": "(111771) 2002 CZ152"
#             },
#             {
#                 "pageid": 2186488,
#                 "ns": 0,
#                 "title": "(111771) 2002 cz152"
#             },
#             {
#                 "pageid": 1205613,
#                 "ns": 0,
#                 "title": "(111785) 2002 CQ186"
#             },
#             {
#                 "pageid": 2186489,
#                 "ns": 0,
#                 "title": "(111785) 2002 cq186"
#             },
#             {
#                 "pageid": 1205619,
#                 "ns": 0,
#                 "title": "(111805) 2002 CZ256"
#             },
#             {
#                 "pageid": 2186490,
#                 "ns": 0,
#                 "title": "(111805) 2002 cz256"
# ...
#                 "title": "(114208) 2002 vh107"
#             },
#             {
#                 "pageid": 1205649,
#                 "ns": 0,
#                 "title": "(114345) 2002 XN72"
#             },
#             {
#                 "pageid": 2186506,
#                 "ns": 0,
#                 "title": "(114345) 2002 xn72"
#             },
#             {
#                 "pageid": 1205652,
#                 "ns": 0,
#                 "title": "(114694) 2003 FC99"
#             },
#             {
#                 "pageid": 2186507,
#                 "ns": 0,
#                 "title": "(114694) 2003 fc99"
#             },
#             {
#                 "pageid": 1205658,
#                 "ns": 0,
#                 "title": "(114710) 2003 GX7"
#             },
#             {
#                 "pageid": 2186508,
#                 "ns": 0,
#                 "title": "(114710) 2003 gx7"
#             },
#             {
#                 "pageid": 1202015,
#                 "ns": 0,
#                 "title": "(11487) 1988 RG10"
#             },
#             {
#                 "pageid": 2186509,
#                 "ns": 0,
#                 "title": "(11487) 1988 rg10"
#             },
#             {
#                 "pageid": 1202021,
#                 "ns": 0,
#                 "title": "(11488) 1988 RM11"
#             },
#             {
#                 "pageid": 2186510,
#                 "ns": 0,
#                 "title": "(11488) 1988 rm11"
#             },
#             {
#                 "pageid": 1215275,
#                 "ns": 0,
#                 "title": "(115052) 2003 RD6"
#             },
#             {
#                 "pageid": 2186511,
#                 "ns": 0,
#                 "title": "(115052) 2003 rd6"
#             },
#             {
#                 "pageid": 1205662,
#                 "ns": 0,
#                 "title": "(116134) 2003 WZ142"
#             },
#             {
#                 "pageid": 2186512,
#                 "ns": 0,
#                 "title": "(116134) 2003 wz142"
#             },
#             {
#                 "pageid": 1205668,
#                 "ns": 0,
#                 "title": "(116238) 2003 YJ12"
#             },
#             {
#                 "pageid": 2186513,
#                 "ns": 0,
#                 "title": "(116238) 2003 yj12"
#             },
#             {
#                 "pageid": 1205672,
#                 "ns": 0,
#                 "title": "(116439) 2003 YN162"
#             },
#             {
#                 "pageid": 2186514,
#                 "ns": 0,
#                 "title": "(116439) 2003 yn162"
#             },
#             {
#                 "pageid": 1205678,
#                 "ns": 0,
#                 "title": "(116567) 2004 BV84"
#             },
#             {
#                 "pageid": 2186515,
#                 "ns": 0,
#                 "title": "(116567) 2004 bv84"
#             },
#             {
#                 "pageid": 1202029,
#                 "ns": 0,
#                 "title": "(11663) 1997 GO24"
#             },
#             {
#                 "pageid": 2186516,
#                 "ns": 0,
#                 "title": "(11663) 1997 go24"
#             },
#             {
#                 "pageid": 1205684,
#                 "ns": 0,
#                 "title": "(116901) 2004 FX147"
#             },
#             {
#                 "pageid": 2186517,
#                 "ns": 0,
#                 "title": "(116901) 2004 fx147"
#             },
#             {
#                 "pageid": 1205689,
#                 "ns": 0,
#                 "title": "(116930) 2004 GE29"
#             },
#             {
#                 "pageid": 2186518,
#                 "ns": 0,
#                 "title": "(116930) 2004 ge29"
#             },
#             {
#                 "pageid": 1205693,
#                 "ns": 0,
#                 "title": "(116954) 2004 HS1"
#             },
#             {
#                 "pageid": 2186519,
#                 "ns": 0,
#                 "title": "(116954) 2004 hs1"
#             },
#             {
#                 "pageid": 1205698,
#                 "ns": 0,
#                 "title": "(116969) 2004 HZ11"
#             },
#             {
#                 "pageid": 2186520,
#                 "ns": 0,
#                 "title": "(116969) 2004 hz11"
#             },
#             {
#                 "pageid": 1205703,
#                 "ns": 0,
#                 "title": "(116970) 2004 HJ15"
#             },
#             {
#                 "pageid": 2186521,
#                 "ns": 0,
#                 "title": "(116970) 2004 hj15"
#             },
#             {
#                 "pageid": 1205709,
#                 "ns": 0,
#                 "title": "(117385) 2004 YN20"
#             },
#             {
#                 "pageid": 2186522,
#                 "ns": 0,
#                 "title": "(117385) 2004 yn20"
#             },
#             {
#                 "pageid": 1205714,
#                 "ns": 0,
#                 "title": "(117389) 2004 YD23"
#             },
#             {
#                 "pageid": 2186523,
#                 "ns": 0,
#                 "title": "(117389) 2004 yd23"
#             },
#             {
#                 "pageid": 1205718,
#                 "ns": 0,
#                 "title": "(117395) 2004 YL35"
#             },
#             {
#                 "pageid": 2186524,
#                 "ns": 0,
#                 "title": "(117395) 2004 yl35"
#             },
#             {
#                 "pageid": 1205724,
#                 "ns": 0,
#                 "title": "(117404) 2005 AC9"
#             },
#             {
#                 "pageid": 2186525,
#                 "ns": 0,
#                 "title": "(117404) 2005 ac9"
#             },
#             {
#                 "pageid": 1205729,
#                 "ns": 0,
#                 "title": "(117423) 2005 AP18"
#             },
#             {
#                 "pageid": 2186526,
#                 "ns": 0,
#                 "title": "(117423) 2005 ap18"
#             },
#             {
#                 "pageid": 1205733,
#                 "ns": 0,
#                 "title": "(117446) 2005 AV45"
#             },
#             {
#                 "pageid": 2186527,
#                 "ns": 0,
#                 "title": "(117446) 2005 av45"
#             },
#             {
#                 "pageid": 1205738,
#                 "ns": 0,
#                 "title": "(117447) 2005 AX46"
#             },
#             {
#                 "pageid": 2186528,
#                 "ns": 0,
#                 "title": "(117447) 2005 ax46"
#             },
#             {
#                 "pageid": 1205744,
#                 "ns": 0,
#                 "title": "(117832) 2005 JL55"
#             },
#             {
#                 "pageid": 2186529,
#                 "ns": 0,
#                 "title": "(117832) 2005 jl55"
#             },
#             {
#                 "pageid": 1205749,
#                 "ns": 0,
#                 "title": "(117851) 2005 JE151"
#             },
#             {
#                 "pageid": 2186530,
#                 "ns": 0,
#                 "title": "(117851) 2005 je151"
#             },
#             {
#                 "pageid": 1222829,
#                 "ns": 0,
#                 "title": "(118228) 1996 TQ66"
#             },
#             {
#                 "pageid": 2186531,
#                 "ns": 0,
#                 "title": "(118228) 1996 tq66"
#             },
#             {
#                 "pageid": 1222825,
#                 "ns": 0,
#                 "title": "(118378) 1999 HT11"
#             },
#             {
#                 "pageid": 2186532,
#                 "ns": 0,
#                 "title": "(118378) 1999 ht11"
#             },
#             {
#                 "pageid": 1222821,
#                 "ns": 0,
#                 "title": "(118379) 1999 HC12"
#             },
#             {
#                 "pageid": 2186533,
#                 "ns": 0,
#                 "title": "(118379) 1999 hc12"
#             },
#             {
#                 "pageid": 1202030,
#                 "ns": 0,
#                 "title": "(11869) 1989 TS2"
#             },
#             {
#                 "pageid": 2186534,
#                 "ns": 0,
#                 "title": "(11869) 1989 ts2"
#             },
#             {
#                 "pageid": 1222817,
#                 "ns": 0,
#                 "title": "(118698) 2000 OY51"
#             },
#             {
#                 "pageid": 2186535,
#                 "ns": 0,
#                 "title": "(118698) 2000 oy51"
#             },
#             {
#                 "pageid": 1205754,
#                 "ns": 0,
#                 "title": "(118815) 2000 SM108"
#             },
#             {
#                 "pageid": 2186536,
#                 "ns": 0,
#                 "title": "(118815) 2000 sm108"
#             },
#             {
#                 "pageid": 1222812,
#                 "ns": 0,
#                 "title": "(119066) 2001 KJ76"
#             },
#             {
#                 "pageid": 2186537,
#                 "ns": 0,
#                 "title": "(119066) 2001 kj76"
#             },
#             {
#                 "pageid": 1222808,
#                 "ns": 0,
#                 "title": "(119067) 2001 KP76"
#             },
#             {
#                 "pageid": 2186538,
#                 "ns": 0,
#                 "title": "(119067) 2001 kp76"
#             },
#             {
#                 "pageid": 1222803,
#                 "ns": 0,
#                 "title": "(119069) 2001 KN77"
#             },
#             {
#                 "pageid": 2186539,
#                 "ns": 0,
#                 "title": "(119069) 2001 kn77"
#             },
#             {
#                 "pageid": 1222800,
#                 "ns": 0,
#                 "title": "(119070) 2001 KP77"
#             },
#             {
#                 "pageid": 2186540,
#                 "ns": 0,
#                 "title": "(119070) 2001 kp77"
#             },
#             {
#                 "pageid": 1222795,
#                 "ns": 0,
#                 "title": "(119473) 2001 UO18"
#             },
#             {
#                 "pageid": 2186541,
#                 "ns": 0,
#                 "title": "(119473) 2001 uo18"
#             },
#             {
#                 "pageid": 1205758,
#                 "ns": 0,
#                 "title": "(119528) 2001 US179"
#             },
#             {
#                 "pageid": 2186542,
#                 "ns": 0,
#                 "title": "(119528) 2001 us179"
#             },
#             {
#                 "pageid": 1222791,
#                 "ns": 0,
#                 "title": "(119951) 2002 KX14"
#             },
#             {
#                 "pageid": 2186543,
#                 "ns": 0,
#                 "title": "(119951) 2002 kx14"
#             },
#             {
#                 "pageid": 1222786,
#                 "ns": 0,
#                 "title": "(119956) 2002 PA149"
#             },
#             {
#                 "pageid": 2186544,
#                 "ns": 0,
#                 "title": "(119956) 2002 pa149"
#             },
#             {
#                 "pageid": 1222783,
#                 "ns": 0,
#                 "title": "(119979) 2002 WC19"
#             },
#             {
#                 "pageid": 2186545,
#                 "ns": 0,
#                 "title": "(119979) 2002 wc19"
#             },
#             {
#                 "pageid": 1222779,
#                 "ns": 0,
#                 "title": "(120132) 2003 FY128"
#             },
#             {
#                 "pageid": 2186546,
#                 "ns": 0,
#                 "title": "(120132) 2003 fy128"
#             },
#             {
#                 "pageid": 1222774,
#                 "ns": 0,
#                 "title": "(120178) 2003 OP32"
#             },
#             {
#                 "pageid": 2186547,
#                 "ns": 0,
#                 "title": "(120178) 2003 op32"
#             },
#             {
#                 "pageid": 1222770,
#                 "ns": 0,
#                 "title": "(120181) 2003 UR292"
#             },
#             {
#                 "pageid": 2186548,
#                 "ns": 0,
#                 "title": "(120181) 2003 ur292"
#             },
#             {
#                 "pageid": 1222767,
#                 "ns": 0,
#                 "title": "(120216) 2004 EW95"
#             },
#             {
#                 "pageid": 2186549,
#                 "ns": 0,
#                 "title": "(120216) 2004 ew95"
#             },
#             {
#                 "pageid": 1222763,
#                 "ns": 0,
#                 "title": "(120348) 2004 TY364"
#             },
#             {
#                 "pageid": 2186550,
#                 "ns": 0,
#                 "title": "(120348) 2004 ty364"
#             },
#             {
#                 "pageid": 1205763,
#                 "ns": 0,
#                 "title": "(120453) 1988 RE12"
#             },
#             {
#                 "pageid": 2186551,
#                 "ns": 0,
#                 "title": "(120453) 1988 re12"
#             },
#             {
#                 "pageid": 1205767,
#                 "ns": 0,
#                 "title": "(120454) 1988 SJ2"
#             },
#             {
#                 "pageid": 2186552,
#                 "ns": 0,
#                 "title": "(120454) 1988 sj2"
#             },
#             {
#                 "pageid": 1202036,
#                 "ns": 0,
#                 "title": "(12054) 1997 TT9"
#             },
#             {
#                 "pageid": 2186553,
#                 "ns": 0,
#                 "title": "(12054) 1997 tt9"
#             },
#             {
#                 "pageid": 1202040,
#                 "ns": 0,
#                 "title": "(12126) 1999 RM11"
#             },
#             {
#                 "pageid": 2186554,
#                 "ns": 0,
#                 "title": "(12126) 1999 rm11"
#             },
#             {
#                 "pageid": 2361301,
#                 "ns": 0,
#                 "title": "(12176) Hidayat"
#             },
#             {
#                 "pageid": 2361305,
#                 "ns": 0,
#                 "title": "(12177) Dhani"
#             },
#             {
#                 "pageid": 2361303,
#                 "ns": 0,
#                 "title": "(12177) Raharto"
#             },
#             {
#                 "pageid": 2361307,
#                 "ns": 0,
#                 "title": "(12179) Taufiq"
#             },
#             {
#                 "pageid": 1205774,
#                 "ns": 0,
#                 "title": "(122391) 2000 QZ75"
#             },
#             {
#                 "pageid": 2186555,
#                 "ns": 0,
#                 "title": "(122391) 2000 qz75"
#             },
#             {
#                 "pageid": 1205778,
#                 "ns": 0,
#                 "title": "(122460) 2000 QB146"
#             },
#             {
#                 "pageid": 2186556,
#                 "ns": 0,
#                 "title": "(122460) 2000 qb146"
#             },
#             {
#                 "pageid": 1205781,
#                 "ns": 0,
#                 "title": "(122581) 2000 RJ24"
#             },
#             {
#                 "pageid": 2186557,
#                 "ns": 0,
#                 "title": "(122581) 2000 rj24"
#             },
#             {
#                 "pageid": 1205786,
#                 "ns": 0,
#                 "title": "(122592) 2000 RE29"
#             },
#             {
#                 "pageid": 2186558,
#                 "ns": 0,
#                 "title": "(122592) 2000 re29"
#             },
#             {
#                 "pageid": 1205794,
#                 "ns": 0,
#                 "title": "(122733) 2000 SK47"
#             },
#             {
#                 "pageid": 2186559,
#                 "ns": 0,
#                 "title": "(122733) 2000 sk47"
#             },
#             {
#                 "pageid": 1205800,
#                 "ns": 0,
#                 "title": "(122860) 2000 ST132"
#             },
#             {
#                 "pageid": 2186560,
#                 "ns": 0,
#                 "title": "(122860) 2000 st132"
#             },
#             {
#                 "pageid": 1205805,
#                 "ns": 0,
#                 "title": "(122862) 2000 SJ134"
#             },
#             {
#                 "pageid": 2186561,
#                 "ns": 0,
#                 "title": "(122862) 2000 sj134"
#             },
#             {
#                 "pageid": 1205809,
#                 "ns": 0,
#                 "title": "(122962) 2000 SG215"
#             },
#             {
#                 "pageid": 2186562,
#                 "ns": 0,
#                 "title": "(122962) 2000 sg215"
#             }
#         ]
#     }
# }

# %% [markdown]
# ##Pengambilan judul laman wikipedia
# - Menggunakan tautan sebelumnya dan menambahkan parameter **continue** untuk mendapatkan laman berikutnya

# %%
urld = urlp

neks = True
i = 1
while neks:
  print(i)
  i += 1
  if i>100:
    neks = False

  datap = urllib.request.urlopen(urlp).read()
  outputp = json.loads(datap)

  if 'continue' in outputp:
    urlt = "&apfrom="+urllib.parse.quote(outputp['continue']['apcontinue'])
    urlp = urld+urlt
    print ('url: ',urlp)
    print ('continue: ',outputp['continue']['apcontinue'])

  if 'continue' not in outputp:
    print ('stop: ',outputp)
    neks = False
# Out:
# 1
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28123509%29_2000_WK183
# continue:  (123509)_2000_WK183
# 2
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28145656%29_4788_P-L
# continue:  (145656)_4788_P-L
# 3
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28162117%29_1998_SD15
# continue:  (162117)_1998_SD15
# 4
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%2818037%29_1999_NA38
# continue:  (18037)_1999_NA38
# 5
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28192642%29_1999_rd32
# continue:  (192642)_1999_rd32
# 6
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28217390%29_2005_cw25
# continue:  (217390)_2005_cw25
# 7
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28228290%29_2000_CS69
# continue:  (228290)_2000_CS69
# 8
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28247341%29_2001_UV209
# continue:  (247341)_2001_UV209
# 9
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28263096%29_2007_TO161
# continue:  (263096)_2007_TO161
# 10
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28279744%29_1998_KM3
# continue:  (279744)_1998_KM3
# 11
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28296672%29_2009_su173
# continue:  (296672)_2009_su173
# 12
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28312459%29_2008_qg44
# continue:  (312459)_2008_qg44
# 13
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28318050%29_2004_FC32
# continue:  (318050)_2004_FC32
# 14
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28334673%29_2003_AL18
# continue:  (334673)_2003_AL18
# 15
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28349916%29_2009_qe59
# continue:  (349916)_2009_qe59
# 16
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28356238%29_2009_sy353
# continue:  (356238)_2009_sy353
# 17
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28362982%29_2013_CT58
# continue:  (362982)_2013_CT58
# 18
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%2838585%29_1999_XD67
# continue:  (38585)_1999_XD67
# 19
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28409718%29_2006_BV225
# continue:  (409718)_2006_BV225
# 20
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28436065%29_2009_RZ73
# continue:  (436065)_2009_RZ73
# 21
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28468852%29_2013_AJ92
# continue:  (468852)_2013_AJ92
# 22
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%28504033%29_2005_UN157
# continue:  (504033)_2005_UN157
# 23
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%285646%29_1990_tr
# continue:  (5646)_1990_tr
# 24
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=%2885490%29_1997_se5
# continue:  (85490)_1997_se5
# 25
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=.ad
# continue:  .ad
# 26
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=1%2B
# continue:  1+
# 27
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=1000000000_%28angka%29
# continue:  1000000000_(angka)
# 28
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=11311_Peleus
# continue:  11311_Peleus
# 29
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=12_and_Holding
# continue:  12_and_Holding
# 30
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=149_SM
# continue:  149_SM
# 31
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=16_Agustus
# continue:  16_Agustus
# 32
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=1892
# continue:  1892
# 33
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=1963_Copa_del_General%C3%ADsimo_Final
# continue:  1963_Copa_del_Generalísimo_Final
# 34
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=1994_Winter_Olympic_Games
# continue:  1994_Winter_Olympic_Games
# 35
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=1998_qa105
# continue:  1998_qa105
# 36
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=1999_xl136
# continue:  1999_xl136
# 37
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=1_korintus_13
# continue:  1_korintus_13
# 38
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=20%2C000_leagues_under_the_sea_%28film_1916%29
# continue:  20,000_leagues_under_the_sea_(film_1916)
# 39
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2000_pf5
# continue:  2000_pf5
# 40
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2001_VB
# continue:  2001_VB
# 41
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2002_AR129
# continue:  2002_AR129
# 42
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2002_aa29
# continue:  2002_aa29
# 43
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2002%E2%80%9303_Football_League_Cup
# continue:  2002–03_Football_League_Cup
# 44
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2003_YZ179
# continue:  2003_YZ179
# 45
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2004_BB75
# continue:  2004_BB75
# 46
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2004_XA45
# continue:  2004_XA45
# 47
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2004_ub
# continue:  2004_ub
# 48
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2005_RD1
# continue:  2005_RD1
# 49
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2005_jp179
# continue:  2005_jp179
# 50
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2006_BO7
# continue:  2006_BO7
# 51
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2006_UM291
# continue:  2006_UM291
# 52
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2006_la
# continue:  2006_la
# 53
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2007_ED125
# continue:  2007_ED125
# 54
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2007_VW83
# continue:  2007_VW83
# 55
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2007_rz19
# continue:  2007_rz19
# 56
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2008_EQ7
# continue:  2008_EQ7
# 57
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2008_SE
# continue:  2008_SE
# 58
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2008_cm74
# continue:  2008_cm74
# 59
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2008_qt3
# continue:  2008_qt3
# 60
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2008_yv32
# continue:  2008_yv32
# 61
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2009_QY33
# continue:  2009_QY33
# 62
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2009_WA105
# continue:  2009_WA105
# 63
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2009_kj30
# continue:  2009_kj30
# 64
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2009_uk14
# continue:  2009_uk14
# 65
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2010_DH56
# continue:  2010_DH56
# 66
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2010_RG42
# continue:  2010_RG42
# 67
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2010_WU25
# continue:  2010_WU25
# 68
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2010_gz6
# continue:  2010_gz6
# 69
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2010_uj
# continue:  2010_uj
# 70
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2011_BB45
# continue:  2011_BB45
# 71
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2011_OV18
# continue:  2011_OV18
# 72
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2011_YN22
# continue:  2011_YN22
# 73
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2011_lk19
# continue:  2011_lk19
# 74
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2011_wu74
# continue:  2011_wu74
# 75
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2012_FM52
# continue:  2012_FM52
# 76
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2012_TD288
# continue:  2012_TD288
# 77
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2012_YR1
# continue:  2012_YR1
# 78
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2012_jh11
# continue:  2012_jh11
# 79
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2012_tq5
# continue:  2012_tq5
# 80
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2013_AN60
# continue:  2013_AN60
# 81
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2013_CY109
# continue:  2013_CY109
# 82
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2013_aa39
# continue:  2013_aa39
# 83
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2013_ck13
# continue:  2013_ck13
# 84
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2013_of
# continue:  2013_of
# 85
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=20_%28Album_Mini%29
# continue:  20_(Album_Mini)
# 86
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2272
# continue:  2272
# 87
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=25_mei
# continue:  25_mei
# 88
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2_Korintus_5%3A17
# continue:  2_Korintus_5:17
# 89
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=2_x_2
# continue:  2_x_2
# 90
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=338_SM
# continue:  338_SM
# 91
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=3_Srikandi
# continue:  3_Srikandi
# 92
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=47_Ursae_Majoris
# continue:  47_Ursae_Majoris
# 93
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=523
# continue:  523
# 94
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=61195_martinoli
# continue:  61195_martinoli
# 95
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=708_SM
# continue:  708_SM
# 96
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=7th_Division_%28Australia%29
# continue:  7th_Division_(Australia)
# 97
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=8th_Asian_Film_Awards
# continue:  8th_Asian_Film_Awards
# 98
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=9_april
# continue:  9_april
# 99
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=A.S._Roma_season_1989%E2%80%931990
# continue:  A.S._Roma_season_1989–1990
# 100
# url:  https://id.wikipedia.org/w/api.php?action=query&format=json&list=allpages&aplimit=500&apfrom=AA_Gym
# continue:  AA_Gym

# %% [markdown]
# - Simpan hasil dari pencarian berdasar kata tertentu
# - Pilih bahasa sebelum melakukan pencarian
